# %% [markdown]
# ## Working with ADCP Data
# *Written by Friedrich Knuth, Rutgers University, June 12, 2018*
#
# In this example we show how to programmatically download and work with 2 Dimensional OOI NetCDF data. We will use data from the ADCP Velocity Profiler (600kHz) deployed at the Coastal Endurance Oregon Inshore Surface Mooring. You will learn:
#
# * how to find the data you are looking for
# * how to use the machine to machine API to request data
# * how to load the NetCDF data into your notebook, once the data request has completed
# * how to explore and plot data
#
# For this example, we are using data from the 600kHaz ADCP Velocity Profiler. You will need the Reference Designator, Stream and Data Delivery Method to make the request to the M2M API.
#
# More information about the instrument can be found here:
# http://ooi.visualocean.net/instruments/view/CE01ISSM-MFD35-04-ADCPTM000
#
# ![CE01ISSM-MFD35-04-ADCPTM000](https://github.com/ooi-data-review/ooi_datateam_notebooks/raw/master/images/CE01ISSM-MFD35-04-ADCPTM000.png)

# %% [markdown]
# ## Request a Dataset

# %%
import requests
import time

# %% [markdown]
# Login in at https://ooinet.oceanobservatories.org/ and obtain your <b>API username and API token</b> under your profile (top right corner), or use the credentials provided below.

# %%
username = ''
token = ''

# %% [markdown]
# Specify your inputs.

# %%
subsite = 'CE01ISSM'
node = 'MFD35'
sensor = '04-ADCPTM000'
method = 'telemetered'
stream = 'adcp_velocity_earth'
beginDT = '2018-03-27T10:32:51.600Z'
endDT = '2018-04-26T10:32:51.600Z'

# %% [markdown]
# Request the data.

# %%
base_url = 'https://ooinet.oceanobservatories.org/api/m2m/12576/sensor/inv/'

data_request_url ='/'.join((base_url,subsite,node,sensor,method,stream))
params = {
    'beginDT':beginDT,
    'endDT':endDT,   
}
r = requests.get(data_request_url, params=params, auth=(username, token))
data = r.json()

# %%
data['allURLs'][0]
# Out:
# u'https://opendap.oceanobservatories.org/thredds/catalog/ooi/ooidatateam@gmail.com/20180612T194019-CE01ISSM-MFD35-04-ADCPTM000-telemetered-adcp_velocity_earth/catalog.html'

# %% [markdown]
# Check if the request has completed.

# %%
# %%time
check_complete = data['allURLs'][1] + '/status.txt'
for i in range(1800): 
    r = requests.get(check_complete)
    if r.status_code == requests.codes.ok:
        print('request completed')
        break
    else:
        time.sleep(1)
# Out:
# request completed
# CPU times: user 290 ms, sys: 27 ms, total: 317 ms
# Wall time: 30.9 s

# %% [markdown]
# ## Load and Plot the Data

# %%
import requests
import re
import os

# !pip install netcdf4
# !pip install dask
# !pip install xarray
import xarray as xr
# Out:
# Requirement already satisfied: netcdf4 in /usr/local/lib/python3.6/dist-packages (1.4.0)
# Requirement already satisfied: cftime in /usr/local/lib/python3.6/dist-packages (from netcdf4) (1.0.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from netcdf4) (1.14.3)
# Requirement already satisfied: cython in /usr/local/lib/python3.6/dist-packages (from cftime->netcdf4) (0.28.3)
# Requirement already satisfied: setuptools>=18.0 in /usr/local/lib/python3.6/dist-packages (from cftime->netcdf4) (39.2.0)
# Requirement already satisfied: dask in /usr/local/lib/python3.6/dist-packages (0.17.5)
# Requirement already satisfied: xarray in /usr/local/lib/python3.6/dist-packages (0.10.7)
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.6/dist-packages (from xarray) (1.14.3)
# Requirement already satisfied: pandas>=0.18.0 in /usr/local/lib/python3.6/dist-packages (from xarray) (0.22.0)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas>=0.18.0->xarray) (2018.4)
# Requirement already satisfied: python-dateutil>=2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.18.0->xarray) (2.5.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2->pandas>=0.18.0->xarray) (1.11.0)

# %% [markdown]
# Parse the thredds server to get a list of all NetCDF files.

# %%
# url = data['allURLs'][0]
url = 'https://opendap.oceanobservatories.org/thredds/catalog/ooi/ooidatateam@gmail.com/20180612T194019-CE01ISSM-MFD35-04-ADCPTM000-telemetered-adcp_velocity_earth/catalog.html'
tds_url = 'https://opendap.oceanobservatories.org/thredds/dodsC'
datasets = requests.get(url).text
urls = re.findall(r'href=[\'"]?([^\'" >]+)', datasets)
x = re.findall(r'(ooi/.*?.nc)', datasets)
for i in x:
    if i.endswith('.nc') == False:
        x.remove(i)
for i in x:
    try:
        float(i[-4])
    except:
        x.remove(i)
datasets = [os.path.join(tds_url, i) for i in x]
datasets
# Out:
# ['https://opendap.oceanobservatories.org/thredds/dodsC/ooi/ooidatateam@gmail.com/20180612T194019-CE01ISSM-MFD35-04-ADCPTM000-telemetered-adcp_velocity_earth/deployment0009_CE01ISSM-MFD35-04-ADCPTM000-telemetered-adcp_velocity_earth_20180403T043300.648000-20180426T103251.600000.nc']

# %% [markdown]
# Load the list of NetCDF files into xarray. Note that this datasets has two dimensions, time and bin. Some variables are dimensioned along just time, others along both time and bin number.

# %%
ds = xr.open_mfdataset(datasets)
ds = ds.swap_dims({'obs': 'time'})
ds = ds.chunk({'time': 100})
ds
# Out:
# <xarray.Dataset>
# Dimensions:                         (bin: 30, time: 281)
# Coordinates:
#     obs                             (time) int32 dask.array<shape=(281,), chunksize=(100,)>
#   * time                            (time) datetime64[ns] 2018-04-03T04:33:00.648000 ...
#     pressure                        (time) float64 dask.array<shape=(281,), chunksize=(100,)>
#     lat                             (time) float64 dask.array<shape=(281,), chunksize=(100,)>
#     lon                             (time) float64 dask.array<shape=(281,), chunksize=(100,)>
# Dimensions without coordinates: bin
# Data variables:
#     deployment                      (time) int32 dask.array<shape=(281,), chunksize=(100,)>
#     id                              (time) |S64 dask.array<shape=(281,), chunksize=(100,)>
#     bin_1_distance                  (time) float32 dask.array<shape=(281,), chunksize=(100,)>
#     cell_length                     (time) float32 dask.array<shape=(281,), chunksize=(100,)>
#     correlation_magnitude_beam1     (time, bin) float32 dask.array<shape=(281, 30), chunksize=(100, 30)>
#     correlation_magnitude_beam2     (time, bin) float32 dask.array<shape=(281, 30), chunksize=(100, 30)>
#     correlation_magnitude_beam3     (time, bin) float32 dask.array<shape=(281, 30), chunksize=(100, 30)>
#     correlation_magnitude_beam4     (time, bin) float32 dask.array<shape=(281, 30), chunksize=(100, 30)>
#     driver_timestamp                (time) datetime64[ns] dask.array<shape=(281,), chunksize=(100,)>
#     echo_intensity_beam1            (time, bin) float32 dask.array<shape=(281, 30), chunksize=(100, 30)>
#     echo_intensity_beam2            (time, bin) float32 dask.array<shape=(281, 30), chunksize=(100, 30)>
#     echo_intensity_beam3            (time, bin) float32 dask.array<shape=(281, 30), chunksize=(100, 30)>
#     echo_intensity_beam4            (time, bin) float32 dask.array<shape=(281, 30), chunksize=(100, 30)>
#     ensemble_number                 (time) float32 dask.array<shape=(281,), chunksize=(100,)>
#     error_velocity                  (time, bin) float32 dask.array<shape=(281, 30), chunksize=(100, 30)>
#     heading                         (time) float32 dask.array<shape=(281,), chunksize=(100,)>
#     ingestion_timestamp             (time) datetime64[ns] dask.array<shape=(281,), chunksize=(100,)>
#     internal_timestamp              (time) datetime64[ns] dask.array<shape=(281,), chunksize=(100,)>
#     num_cells                       (time) float32 dask.array<shape=(281,), chunksize=(100,)>
#     percent_bad_beams               (time, bin) float32 dask.array<shape=(281, 30), chunksize=(100, 30)>
#     percent_good_3beam              (time, bin) float32 dask.array<shape=(281, 30), chunksize=(100, 30)>
#     percent_good_4beam              (time, bin) float32 dask.array<shape=(281, 30), chunksize=(100, 30)>
#     percent_transforms_reject       (time, bin) float32 dask.array<shape=(281, 30), chunksize=(100, 30)>
#     pitch                           (time) float32 dask.array<shape=(281,), chunksize=(100,)>
#     port_timestamp                  (time) datetime64[ns] dask.array<shape=(281,), chunksize=(100,)>
#     preferred_timestamp             (time) object dask.array<shape=(281,), chunksize=(100,)>
#     provenance                      (time) |S64 dask.array<shape=(281,), chunksize=(100,)>
#     roll                            (time) float32 dask.array<shape=(281,), chunksize=(100,)>
#     salinity                        (time) float32 dask.array<shape=(281,), chunksize=(100,)>
#     sysconfig_vertical_orientation  (time) float32 dask.array<shape=(281,), chunksize=(100,)>
#     temperature                     (time) float32 dask.array<shape=(281,), chunksize=(100,)>
#     transducer_depth                (time) float32 dask.array<shape=(281,), chunksize=(100,)>
#     water_velocity_east             (time, bin) float32 dask.array<shape=(281, 30), chunksize=(100, 30)>
#     water_velocity_north            (time, bin) float32 dask.array<shape=(281, 30), chunksize=(100, 30)>
#     water_velocity_up               (time, bin) float32 dask.array<shape=(281, 30), chunksize=(100, 30)>
#     corrected_echo_intensity_beam1  (time, bin) float64 dask.array<shape=(281, 30), chunksize=(100, 30)>
#     corrected_echo_intensity_beam2  (time, bin) float64 dask.array<shape=(281, 30), chunksize=(100, 30)>
#     corrected_echo_intensity_beam3  (time, bin) float64 dask.array<shape=(281, 30), chunksize=(100, 30)>
#     corrected_echo_intensity_beam4  (time, bin) float64 dask.array<shape=(281, 30), chunksize=(100, 30)>
#     eastward_seawater_velocity      (time, bin) float64 dask.array<shape=(281, 30), chunksize=(100, 30)>
#     northward_seawater_velocity     (time, bin) float64 dask.array<shape=(281, 30), chunksize=(100, 30)>
#     upward_seawater_velocity        (time, bin) float64 dask.array<shape=(281, 30), chunksize=(100, 30)>
#     error_seawater_velocity         (time, bin) float64 dask.array<shape=(281, 30), chunksize=(100, 30)>
#     bin_depths                      (time, bin) float64 dask.array<shape=(281, 30), chunksize=(100, 30)>
# Attributes:
#     _NCProperties:                      version=1|netcdflibversion=4.4.1.1|hd...
#     node:                               MFD35
#     comment:
#     publisher_email:
#     sourceUrl:                          http://oceanobservatories.org/
#     collection_method:                  telemetered
#     stream:                             adcp_velocity_earth
#     featureType:                        point
#     creator_email:
#     publisher_name:                     Ocean Observatories Initiative
#     date_modified:                      2018-06-12T19:40:35.193785
#     keywords:
#     cdm_data_type:                      Point
#     references:                         More information can be found at http...
#     Metadata_Conventions:               Unidata Dataset Discovery v1.0
#     date_created:                       2018-06-12T19:40:35.193783
#     id:                                 CE01ISSM-MFD35-04-ADCPTM000-telemeter...
#     requestUUID:                        dfe0cb49-f262-4acd-a858-e97eca5f4d22
#     contributor_role:
#     summary:                            Dataset Generated by Stream Engine fr...
#     keywords_vocabulary:
#     institution:                        Ocean Observatories Initiative
#     naming_authority:                   org.oceanobservatories
#     feature_Type:                       point
#     infoUrl:                            http://oceanobservatories.org/
#     license:
#     contributor_name:
#     uuid:                               dfe0cb49-f262-4acd-a858-e97eca5f4d22
#     creator_name:                       Ocean Observatories Initiative
#     title:                              Data produced by Stream Engine versio...
#     sensor:                             04-ADCPTM000
#     standard_name_vocabulary:           NetCDF Climate and Forecast (CF) Meta...
#     acknowledgement:
#     Conventions:                        CF-1.6
#     project:                            Ocean Observatories Initiative
#     source:                             CE01ISSM-MFD35-04-ADCPTM000-telemeter...
#     publisher_url:                      http://oceanobservatories.org/
#     creator_url:                        http://oceanobservatories.org/
#     nodc_template_version:              NODC_NetCDF_TimeSeries_Orthogonal_Tem...
#     subsite:                            CE01ISSM
#     processing_level:                   L2
#     history:                            2018-06-12T19:40:35.193747 generated ...
#     Manufacturer:                       Teledyne RDI
#     ModelNumber:                        WHS600-500
#     SerialNumber:                       21522
#     Description:                        ADCP Velocity Profiler (short range):...
#     FirmwareVersion:                    Not specified.
#     SoftwareVersion:                    Not specified.
#     AssetUniqueID:                      CGINS-ADCPTM-21522
#     Notes:                              Not specified.
#     Owner:                              Not specified.
#     RemoteResources:                    []
#     ShelfLifeExpirationDate:            Not specified.
#     Mobile:                             False
#     AssetManagementRecordLastModified:  2018-05-21T12:22:49.662000
#     time_coverage_start:                2018-04-03T04:33:00.648000
#     time_coverage_end:                  2018-04-26T10:32:51.600000
#     time_coverage_resolution:           P7148.72S
#     geospatial_lat_min:                 44.65685
#     geospatial_lat_max:                 44.65685
#     geospatial_lat_units:               degrees_north
#     geospatial_lat_resolution:          0.1
#     geospatial_lon_min:                 -124.09553
#     geospatial_lon_max:                 -124.09553
#     geospatial_lon_units:               degrees_east
#     geospatial_lon_resolution:          0.1
#     geospatial_vertical_units:          meters
#     geospatial_vertical_resolution:     0.1
#     geospatial_vertical_positive:       down
#     DODS.strlen:                        36
#     DODS.dimName:                       string36
#     DODS_EXTRA.Unlimited_Dimension:     obs

# %% [markdown]
# Extract the bin depths, east, north and west values along the time dimensions. Note the .T for two dimensional variables.

# %%
time = ds['time'].data
bin_depths = ds['bin_depths'].data.T
east = ds['eastward_seawater_velocity'].data.T
north = ds['northward_seawater_velocity'].data.T
up = ds['upward_seawater_velocity'].data.T

# %% [markdown]
# Next we will plot the data.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# To screen out surface noise velocities we will set the colorbar limit to the 90th percentile of the data.

# %%
lim_east = float("%2.2f" % np.nanpercentile(east, 90))
lim_north = float("%2.2f" % np.nanpercentile(north, 90))
lim_up = float("%2.2f" % np.nanpercentile(up, 90))
u_v_w = max([lim_east, lim_north, lim_up])

# %% [markdown]
# And plot.

# %%
plt.close()
fig, axes = plt.subplots(3, sharex=True)
fig.set_size_inches(20, 9)

p0 = axes[0].pcolormesh(time, bin_depths, east, cmap='RdBu',vmin=-u_v_w,vmax=u_v_w)
axes[0].set_ylim(5,25)
axes[0].set_title('Eastward Velocity (u)')
axes[0].invert_yaxis()

p1 = axes[1].pcolormesh(time, bin_depths, north, cmap='RdBu',vmin=-u_v_w,vmax=u_v_w)
axes[1].set_title('Northward Velocity (v)')
axes[1].set_ylim(5,25)
axes[1].invert_yaxis()
axes[1].set_ylabel('Depth')

p2 = axes[2].pcolormesh(time, bin_depths, up, cmap='RdBu',vmin=-u_v_w,vmax=u_v_w)
axes[2].set_title('Upward Velocity (w)')
axes[2].set_ylim(5,25)
axes[2].invert_yaxis()
axes[2].set_xlabel('Time')

fig.colorbar(p0,ax=axes.ravel().tolist(), label='m/s')

plt.show()
