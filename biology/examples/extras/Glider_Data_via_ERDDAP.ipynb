# %% [markdown]
# # Glider Data via ERDDAP
# *Compiled by Sage Lichtenwalner, Rutgers University, June 6, 2018*
#
# *This example is largely based on a notebook by [Filipe Fernandes's](https://github.com/ioos/BioData-Training-Workshop/blob/master/notebooks/intro_errdapy-IOOS.ipynb), presented at the IOOS Biological Data Training Workshop. Thanks Filipe!*

# %% [markdown]
# ERDDAP data servers provide an easy to use RESTful API that make it easy to search for and request data.  There are many ERDDAP servers now available including [NOAA Coastwatch](erddap coastwatch), the [IOOS Glider DAC](https://data.ioos.us/gliders/erddap/index.html), and the  [OOI](http://oceanobservatories.org/erddap-server/).
#
# For this example, we're going to grab OOI glider data that is stored in the IOOS Glider DAC.
#
# A typical ERDDAP URL to request data looks like this:
#
# [https://data.ioos.us/gliders/erddap/tabledap/whoi_406-20160902T1700.mat?depth,latitude,longitude,salinity,temperature,time&time>=2016-07-10T00:00:00Z&time<=2017-02-10T00:00:00Z
# &latitude>=38.0&latitude<=41.0&longitude>=-72.0&longitude<=-69.0](https://data.ioos.us/gliders/erddap/tabledap/whoi_406-20160902T1700.mat?depth,latitude,longitude,salinity,temperature,time&time>=2016-07-10T00:00:00Z&time<=2017-02-10T00:00:00Z&latitude>=38.0&latitude<=41.0&longitude>=-72.0&longitude<=-69.0)

# %% [markdown]
# It's a mouthful, but it can easily be broken down into smaller parts.
#
# * **server**: https://data.ioos.us/gliders/erddap/
# * **protocol**: tabledap
# * **dataet_id**: blue-20160818T1448.csv
# * **variables**: depth,latitude,longitude,temperature,time
# * **constraints**:
#     - time>=2016-07-10T00:00:00Z
#     - time<=2017-02-10T00:00:00Z
#     - latitude>=38.0
#     - latitude<=41.0
#     - longitude>=-72.0
#     - longitude<=-69.0

# %% [markdown]
# ## We can use *erddapy* to help us make these URLs
#
# ![tar.png](https://imgs.xkcd.com/comics/tar.png)

# %%
# !pip install xarray

# !pip install erddapy
from erddapy import ERDDAP
# Out:
# Requirement already satisfied: xarray in /usr/local/lib/python3.6/dist-packages (0.10.6)
# Requirement already satisfied: pandas>=0.18.0 in /usr/local/lib/python3.6/dist-packages (from xarray) (0.22.0)
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.6/dist-packages (from xarray) (1.14.3)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas>=0.18.0->xarray) (2018.4)
# Requirement already satisfied: python-dateutil>=2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.18.0->xarray) (2.5.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2->pandas>=0.18.0->xarray) (1.11.0)
# Requirement already satisfied: erddapy in /usr/local/lib/python3.6/dist-packages (0.1.8)
# Requirement already satisfied: pandas>=0.20.3 in /usr/local/lib/python3.6/dist-packages (from erddapy) (0.22.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from erddapy) (2.18.4)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.20.3->erddapy) (1.14.3)
# Requirement already satisfied: python-dateutil>=2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.20.3->erddapy) (2.5.3)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas>=0.20.3->erddapy) (2018.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->erddapy) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->erddapy) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->erddapy) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->erddapy) (2018.4.16)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2->pandas>=0.20.3->erddapy) (1.11.0)

# %% [markdown]
# # Part 1 - Let's Grab Some Data
#
# * Were going going to use the [IOOS Glider DAC](https://data.ioos.us/gliders/erddap/index.html)
#   * It includes gliders from many providers, including OOI
#   * The data is provided in profile format, which makes it easier to use
#
# * If we know the dataset ID we're interested in, we can request data

# %%
server = 'https://data.ioos.us/gliders/erddap'

dataset_id = 'whoi_406-20160902T1700'

constraints = {
    'time>=': '2016-07-10T00:00:00Z',
    'time<=': '2017-02-10T00:00:00Z',
    'latitude>=': 38.0,
    'latitude<=': 41.0,
    'longitude>=': -72.0,
    'longitude<=': -69.0,
}

variables = [
 'depth',
 'latitude',
 'longitude',
 'salinity',
 'temperature',
 'time',
]

# %%
e = ERDDAP(
    server=server,
    protocol='tabledap',
    response='nc'
)

e.dataset_id=dataset_id
e.constraints=constraints
e.variables=variables

print(e.get_download_url())
# Out:
# https://data.ioos.us/gliders/erddap/tabledap/whoi_406-20160902T1700.nc?depth,latitude,longitude,salinity,temperature,time&time>=1468108800.0&time<=1486684800.0&latitude>=38.0&latitude<=41.0&longitude>=-72.0&longitude<=-69.0

# %% [markdown]
# ## Talk is cheap, so me the data!
#
# There are a few methods you can use to get the data in a usable format:
# * *to_pandas()*
# * *to_xarray()*

# %%
df = e.to_pandas(
    index_col='time',
    parse_dates=True,
    skiprows=(1,)  # units information can be dropped.
).dropna()

df.head()
# Out:
#                      depth   latitude  longitude   salinity  temperature
# time
# 2016-09-03 20:15:46   5.35  40.990881  -71.12439  32.245422      20.6620
# 2016-09-03 20:15:46   6.09  40.990881  -71.12439  32.223183      20.6512
# 2016-09-03 20:15:46   6.72  40.990881  -71.12439  32.237950      20.6047
# 2016-09-03 20:15:46   7.37  40.990881  -71.12439  32.235470      20.5843
# 2016-09-03 20:15:46   8.43  40.990881  -71.12439  32.224503      20.5691

# %%
ds = e.to_xarray(decode_times=False)

ds['temperature']
# Out:
# <xarray.DataArray 'temperature' (row: 48490)>
# array([20.662 , 20.6512, 20.6047, ..., 18.9417, 19.0459, 19.2737],
#       dtype=float32)
# Coordinates:
#     depth      (row) float32 ...
#     latitude   (row) float64 ...
#     longitude  (row) float64 ...
#     time       (row) float64 ...
# Dimensions without coordinates: row
# Attributes:
#     _ChunkSizes:          73
#     actual_range:         [ 9.9473 22.6177]
#     ancillary_variables:  qartod_temperature_climatological_flag qartod_tempe...
#     colorBarMaximum:      32.0
#     colorBarMinimum:      0.0
#     instrument:           instrument_ctd
#     ioos_category:        Temperature
#     long_name:            Sea Water Temperature
#     observation_type:     measured
#     platform:             platform
#     standard_name:        sea_water_temperature
#     units:                Celsius
#     valid_max:            40.0
#     valid_min:            -5.0

# %% [markdown]
# ## Let's plot the data

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
fig, ax = plt.subplots(figsize=(17, 5))
kw = dict(s=15, c=df['temperature'], marker='o', edgecolor='none')
cs = ax.scatter(df.index, df['depth'], **kw, cmap='RdYlBu_r')

ax.invert_yaxis()
ax.set_xlim(df.index[0], df.index[-1])
xfmt = mdates.DateFormatter('%H:%Mh\n%d-%b')
ax.xaxis.set_major_formatter(xfmt)

cbar = fig.colorbar(cs, orientation='vertical', extend='both')
cbar.ax.set_ylabel('Temperature ($^\circ$C)')
ax.set_ylabel('Depth (m)');

# %% [markdown]
# # Part 2 - Searching for Datasets
#
# * [ERDDAP](https://data.ioos.us/gliders/erddap/search/advanced.html?page=1&itemsPerPage=1000) also provides a way to search for datasets
# * And we can use *erddapy* to search for datasets interactively

# %%
e = ERDDAP(
    server='https://data.ioos.us/gliders/erddap'
)

# %%
import pandas as pd

# Grab every dataset available
datasets = pd.read_csv(e.get_search_url(response='csv', search_for='all'))

# %%
'We have {} tabledap, {} griddap, and {} wms endpoints.'.format(
    len(set(datasets['tabledap'].dropna())),
    len(set(datasets['griddap'].dropna())),
    len(set(datasets['wms'].dropna()))
)
# Out:
# 'We have 434 tabledap, 0 griddap, and 0 wms endpoints.'

# %%
datasets.head()
# Out:
#    griddap                                             Subset  \
# 0      NaN  https://data.ioos.us/gliders/erddap/tabledap/a...
# 1      NaN  https://data.ioos.us/gliders/erddap/tabledap/a...
# 2      NaN  https://data.ioos.us/gliders/erddap/tabledap/a...
# 3      NaN  https://data.ioos.us/gliders/erddap/tabledap/a...
# 4      NaN  https://data.ioos.us/gliders/erddap/tabledap/a...
#
#                                             tabledap  \
# 0  https://data.ioos.us/gliders/erddap/tabledap/a...
# 1  https://data.ioos.us/gliders/erddap/tabledap/a...
# 2  https://data.ioos.us/gliders/erddap/tabledap/a...
# 3  https://data.ioos.us/gliders/erddap/tabledap/a...
# 4  https://data.ioos.us/gliders/erddap/tabledap/a...
#
#                                         Make A Graph  wms  files  \
# 0  https://data.ioos.us/gliders/erddap/tabledap/a...  NaN    NaN
# 1  https://data.ioos.us/gliders/erddap/tabledap/a...  NaN    NaN
# 2  https://data.ioos.us/gliders/erddap/tabledap/a...  NaN    NaN
# 3  https://data.ioos.us/gliders/erddap/tabledap/a...  NaN    NaN
# 4  https://data.ioos.us/gliders/erddap/tabledap/a...  NaN    NaN
#
#                                                Title  \
# 0  * The List of All Active Datasets in this ERDD...
# 1                                   All aoml Gliders
# 2                                   All aoos Gliders
# 3                                   All bios Gliders
# 4                                  All corie Gliders
#
#                                              Summary  \
# 0  This dataset is a table which has a row of inf...
# 1  Seaglider data gathered as part of the Sustain...
# 2  Shipboard observations of marine mammal distri...
# 3  The Bermuda Institute of Ocean Sciences MAGIC ...
# 4  Slocum glider dataset gathered as part of the ...
#
#                                                 FGDC  \
# 0                                                NaN
# 1  https://data.ioos.us/gliders/erddap/metadata/f...
# 2  https://data.ioos.us/gliders/erddap/metadata/f...
# 3  https://data.ioos.us/gliders/erddap/metadata/f...
# 4  https://data.ioos.us/gliders/erddap/metadata/f...
#
#                                            ISO 19115  \
# 0                                                NaN
# 1  https://data.ioos.us/gliders/erddap/metadata/i...
# 2  https://data.ioos.us/gliders/erddap/metadata/i...
# 3  https://data.ioos.us/gliders/erddap/metadata/i...
# 4  https://data.ioos.us/gliders/erddap/metadata/i...
#
#                                                 Info  \
# 0  https://data.ioos.us/gliders/erddap/info/allDa...
# 1  https://data.ioos.us/gliders/erddap/info/allao...
# 2  https://data.ioos.us/gliders/erddap/info/allao...
# 3  https://data.ioos.us/gliders/erddap/info/allbi...
# 4  https://data.ioos.us/gliders/erddap/info/allco...
#
#                        Background Info  \
# 0  https://data.ioos.us/gliders/erddap
# 1  http://data.ioos.us/gliders/erddap/
# 2  http://data.ioos.us/gliders/erddap/
# 3  http://data.ioos.us/gliders/erddap/
# 4  http://data.ioos.us/gliders/erddap/
#
#                                                  RSS  \
# 0                                                NaN
# 1  https://data.ioos.us/gliders/erddap/rss/allaom...
# 2  https://data.ioos.us/gliders/erddap/rss/allaoo...
# 3  https://data.ioos.us/gliders/erddap/rss/allbio...
# 4  https://data.ioos.us/gliders/erddap/rss/allcor...
#
#                                                Email  \
# 0                                                NaN
# 1  https://data.ioos.us/gliders/erddap/subscripti...
# 2  https://data.ioos.us/gliders/erddap/subscripti...
# 3  https://data.ioos.us/gliders/erddap/subscripti...
# 4  https://data.ioos.us/gliders/erddap/subscripti...
#
#                                          Institution       Dataset ID
# 0                                    IOOS Glider DAC      allDatasets
# 1  National Oceanic and Atmospheric Administratio...   allaomlGliders
# 2  University of Alaska Fairbanks, College of Fis...   allaoosGliders
# 3               Bermuda Institute of Ocean Sciences    allbiosGliders
# 4                 Oregon Health & Science University  allcorieGliders

# %% [markdown]
# ## Let's refine our search
#
# Let's narrow the search area, time span, and look for *sea_water_temperature* only.

# %%
kw = {
    'standard_name': 'sea_water_temperature',
    'min_lon': -72.0,
    'max_lon': -69.0,
    'min_lat': 38.0,
    'max_lat': 41.0,
    'min_time': '2018-01-10T00:00:00Z',
    'max_time': '2019-01-10T00:00:00Z',
    'cdm_data_type': 'trajectoryprofile'
}

# %%
search_url = e.get_search_url(response='csv', **kw)
print(search_url)

# Grab the results
search = pd.read_csv(search_url)

# Extract the IDs
gliders = search['Dataset ID'].values

msg = 'Found {} Glider Datasets:\n\n{}'.format
print(msg(len(gliders), '\n'.join(gliders)))
# Out:
# https://data.ioos.us/gliders/erddap/search/advanced.csv?page=1&itemsPerPage=1000&protocol=(ANY)&cdm_data_type=trajectoryprofile&institution=(ANY)&ioos_category=(ANY)&keywords=(ANY)&long_name=(ANY)&standard_name=sea_water_temperature&variableName=(ANY)&minLon=-72.0&maxLon=-69.0&minLat=38.0&maxLat=41.0&minTime=1515542400.0&maxTime=1547078400.0
# Found 6 Glider Datasets:
#
# allrutgersGliders
# cp_336-20180126T0000
# cp_339-20180126T0000
# cp_380-20180126T0000
# sp022-20180422T1229
# sp066-20171129T1616

# %% [markdown]
# # Part 3 - Dataset Metadata
#
# Once we know the *Dataset IDs* we can explore its metadata with `get_info_url()`

# %%
info_url = e.get_info_url(dataset_id=gliders[2], response='csv')
info = pd.read_csv(info_url)

print(gliders[2])
info.head(10) # First 10 attributes
# Out:
# cp_339-20180126T0000
#     Row Type Variable Name            Attribute Name Data Type  \
# 0  attribute     NC_GLOBAL            acknowledgment    String
# 1  attribute     NC_GLOBAL             cdm_data_type    String
# 2  attribute     NC_GLOBAL     cdm_profile_variables    String
# 3  attribute     NC_GLOBAL  cdm_trajectory_variables    String
# 4  attribute     NC_GLOBAL          contributor_name    String
# 5  attribute     NC_GLOBAL          contributor_role    String
# 6  attribute     NC_GLOBAL               Conventions    String
# 7  attribute     NC_GLOBAL             creator_email    String
# 8  attribute     NC_GLOBAL              creator_name    String
# 9  attribute     NC_GLOBAL               creator_url    String
#
#                                                Value
# 0  Funding provided by the National Science Found...
# 1                                  TrajectoryProfile
# 2  profile_id, time, latitude, longitude, time_uv...
# 3                                 trajectory, wmo_id
# 4  Paul Matthias,Peter Brickley,Sheri White,Diana...
# 5  CGSN Program Manager,CGSN Operations Engineer,...
# 6     Unidata Dataset Discovery v1.0, COARDS, CF-1.6
# 7                         kerfoot@marine.rutgers.edu
# 8                                       John Kerfoot
# 9                  http://www.whoi.edu/ooi_cgsn/home

# %%
# Let's pull out the values for one of the variables
cdm_profile_variables = info.loc[
    info['Attribute Name'] == 'cdm_profile_variables', 'Value'
]

print(''.join(cdm_profile_variables))
# Out:
# profile_id, time, latitude, longitude, time_uv, lat_uv, lon_uv, u, v

# %% [markdown]
# ## Finding variable names using attributes

# %%
# Find a variable name based on it's CF Compliant standard name
e.get_var_by_attr(
    dataset_id='cp_335-20170116T1459',
    standard_name='sea_water_temperature'
)
# Out:
# ['temperature']

# %%
# Now let's find a few of them at once
standard_names=['sea_water_temperature', 'sea_water_practical_salinity']
variables = e.get_var_by_attr(
    dataset_id=dataset_id, 
    standard_name=lambda v: v in standard_names
)
variables
# Out:
# ['temperature', 'salinity']

# %% [markdown]
# ## Finding coordinate variables

# %%
axis = e.get_var_by_attr(
    dataset_id='cp_339-20180126T0000',
    axis=lambda v: v in ['X', 'Y', 'Z', 'T']
)
axis
# Out:
# ['longitude',
#  'depth',
#  'time',
#  'pressure',
#  'precise_lat',
#  'precise_time',
#  'latitude',
#  'precise_lon']

# %% [markdown]
# # Putting everything together
#
# Let's find all of the gliders that flew within the Pioneer Array during 2018.

# %%
constraints = {
    'time>=': '2018-01-01T00:00:00Z',
    'time<=': '2019-01-01T00:00:00Z',
    'latitude>=': 38.0,
    'latitude<=': 41.0,
    'longitude>=': -72.0,
    'longitude<=': -69.0,
}

variables = [
 'depth',
 'latitude',
 'longitude',
 'salinity',
 'temperature',
 'time',
]

# %%
from requests.exceptions import HTTPError

def download_csv(url):
    return pd.read_csv(
        url, index_col='time', parse_dates=True, skiprows=[1]
)

dfs = {}
for glider in gliders:
    print(glider)
    try:
        download_url = e.get_download_url(
            dataset_id=glider,
            protocol='tabledap',
            variables=variables,
            response='csv',
            constraints=constraints
        )
    except HTTPError:
        continue
    dfs.update({glider: download_csv(download_url)})
# Out:
# allrutgersGliders
# cp_336-20180126T0000
# cp_339-20180126T0000
# cp_380-20180126T0000
# sp022-20180422T1229
# sp066-20171129T1616

# %% [markdown]
# We can use [Folium](http://python-visualization.github.io/folium/) to create an interactive map of all of the glider tracks using leaflet.js.

# %%
# !pip install folium 
import folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.6/dist-packages (0.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from folium) (2.18.4)
# Requirement already satisfied: branca in /usr/local/lib/python3.6/dist-packages (from folium) (0.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from folium) (2.10)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from folium) (1.11.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (2018.4.16)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (1.22)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->folium) (1.0)

# %%
def plot_track(df, name, color='orange'):
    df = df.reset_index().drop_duplicates(['latitude','longitude'], keep='first').sort_values('time')

    locations = list(zip(df['latitude'].values, df['longitude'].values))
    folium.PolyLine(
        locations=locations,
        color=color,
        weight=8,
        opacity=0.7,
        tooltip=name
    ).add_to(m)
    print(color)

# %%
import matplotlib.colors as mc
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
print(colors)

tiles = ('http://services.arcgisonline.com/arcgis/rest/services/'
         'World_Topo_Map/MapServer/MapServer/tile/{z}/{y}/{x}')

m = folium.Map(location=(40.3052, -70.8833), zoom_start=7,
               tiles=tiles, attr='ESRI')

k=0
for name, df in list(dfs.items()):
    plot_track( df, name, color=mc.to_hex(colors[k]) )
    k = k+1;

m #Display the map
# Out:
# [(0.2980392156862745, 0.4470588235294118, 0.6901960784313725), (0.3333333333333333, 0.6588235294117647, 0.40784313725490196), (0.7686274509803922, 0.3058823529411765, 0.3215686274509804), (0.5058823529411764, 0.4470588235294118, 0.6980392156862745), (0.8, 0.7254901960784313, 0.4549019607843137), (0.39215686274509803, 0.7098039215686275, 0.803921568627451)]
# #4c72b0
# #55a868
# #c44e52
# #8172b2
# #ccb974
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def glider_scatter(df, ax, glider):
    ax.scatter(df['temperature'], df['salinity'], s=10, alpha=0.5, label=glider)
    
fig, ax = plt.subplots(figsize=(7, 7))
ax.set_ylabel('Salinity')
ax.set_xlabel('Temperature')
ax.grid(True)

for glider, df in dfs.items():
    glider_scatter(df, ax, glider)
    
leg = ax.legend()
ax.set_ylim(20, 41)
ax.set_xlim(2.5, 26);

# %% [markdown]
# # References
#
# * Check out the [erddapy documentation](https://pyoceans.github.io/erddapy/) for more information on using the library, especially the [Quick Intro](https://pyoceans.github.io/erddapy/quick_intro.html).
